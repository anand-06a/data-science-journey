# %%
l=['python','java','c','c++','core']
list(filter(lambda x:x.startswith('c'),l))
# Out:
# ['c', 'c++', 'core']

# %%
l1=[1,2,4]
l2=[5,7,8]
# 6,9,12
list(map(lambda x,y:x+y,l1,l2))
# Out:
# [6, 9, 12]

# %%
l1=[1,2,4,9,13,90]
#['odd',even','even','odd','odd','even']
list(map(lambda x: 'even'if x%2==0 else 'odd',l1))
# Out:
# ['odd', 'even', 'even', 'odd', 'odd', 'even']

# %%
l1=[1,2,4,9,13,90]
# 2 2 8 18 26 180
list(map(lambda x: x+x,l1))
# Out:
# [2, 4, 8, 18, 26, 180]

# %%
# reduce
l=[4,7,9,10]
#sum(l)
#30
#import functools
#from functools import reduce
#(reduce(x,y:x+y),l)

# %%
l=[4,7,9,10]
import functools
functools.reduce(lambda x,y:x+y,l)
# Out:
# 30

# %%
l=[4,7,9,10]
import functools
functools.reduce(lambda x,y:x*y,l)
# Out:
# 2520

# %%
l=[4,7,9,10]
import functools
functools.reduce(lambda x,y:x if x>y else y ,l)
# Out:
# 10

# %%
l=[4,7,9,10]
import functools
functools.reduce(lambda x,y:x if x<y else y ,l)
# Out:
# 4

# %%
import datetime
datetime.datetime.now()
# Out:
# datetime.datetime(2026, 6, 25, 16, 45, 56, 809625)

# %%
import datetime
datetime.datetime.now()
# Out:
# datetime.datetime(2026, 6, 25, 16, 46, 45, 954144)

# %%
import datetime
datetime.datetime.now()
# Out:
# datetime.datetime(2026, 6, 25, 16, 47, 39, 909814)
