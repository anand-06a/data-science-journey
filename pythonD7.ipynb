# %%
# tuple unpacking
a,b,*c=9,10,15,89,90,890,67,56
print(c)
# Out:
# [15, 89, 90, 890, 67, 56]

# %%
a=(1,2,3)
b=(7,8,9)
tuple(zip(a,b))
# Out:
# ((1, 7), (2, 8), (3, 9))

# %%
a=(1,2,3)
b=(7,8,9,10)
tuple(zip(a,b))
# Out:
# ((1, 7), (2, 8), (3, 9))

# %%
a=(1,2,3,90)
b=(7,8,9,10)
tuple(zip(a,b))
# Out:
# ((1, 7), (2, 8), (3, 9), (90, 10))

# %%
a=(1,2,3,90,95)
b=(7,8,9,10)
tuple(zip(a,b))
# Out:
# ((1, 7), (2, 8), (3, 9), (90, 10))

# %%
t=(1,2,3,3,4,5)
t.count(3)
# Out:
# 2

# %%
t.index(3)
# Out:
# 2

# %%
l=[9,4,5,6]
t=tuple(l)
t
# Out:
# (9, 4, 5, 6)

# %%
t1=(1,2,3,4)
t2=(6,7,4,6)
t1+t2
# Out:
# (1, 2, 3, 4, 6, 7, 4, 6)

# %%
for i in t:
    print(i,end=' ')
# Out:
# 9 4 5 6

# %%
# set   it store only value
s=[]
type(s)
# Out:
# list

# %%
s={}
type(s)
# Out:
# dict

# %%
s=set()
type(s)
# Out:
# set

# %%
l=[9,3,2,0]
l
# Out:
# [9, 3, 2, 0]

# %%
l={9,3,2,0,'p',9999,9.8,8965}
l # set is unorder
# Out:
# {0, 2, 3, 8965, 9, 9.8, 9999, 'p'}

# %%
s={1,2,4,5,6,7,7,8,7,7}
s # set will remove the duplicate element
# Out:
# {1, 2, 4, 5, 6, 7, 8}

# %%
l=[9,8,9,9,0]
set(l) # remove the duplicate from the list
# Out:
# {0, 8, 9}

# %%
s={1,2,3,[4,6,7]}
s
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_17792\4023792612.py in <module>
# ----> 1 s={1,2,3,[4,6,7]}
#       2 s
#
# TypeError: unhashable type: 'list'

# %%
s={1,2,3,(4,6,7)}
s
# Out:
# {(4, 6, 7), 1, 2, 3}

# %%
s={1,2,3,{4,6,7}}
s
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_17792\2350817591.py in <module>
# ----> 1 s={1,2,3,{4,6,7}}
#       2 s
#
# TypeError: unhashable type: 'set'

# %%
s1={1,2,3}
s2={4,5,6}
s1.union(s2)
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
s1={1,2,3}
s2={4,5,6}
s1|s2
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
s1={1,2,3,4,5}
s2={4,5,6}
s1&s2  # intersection
# Out:
# {4, 5}

# %%
s1-s2 # difference
# Out:
# {1, 2, 3}

# %%
s2-s1
# Out:
# {6}

# %%
s1={3,5,8,9}
s2={7,8}
s1-s2
# Out:
# {3, 5, 9}

# %%
# symmetric difference
s1={1,2,3,4,5,7}
s2={4,5,6,7,8}
s1^s2
# Out:
# {1, 2, 3, 6, 8}

# %%
s1={3,5,8,9}
s2={7,8}
s1^s2
# Out:
# {3, 5, 7, 9}

# %%
s={5,7,9}
s.add(50)
s
# Out:
# {5, 7, 9, 50}

# %%
s={5,7,9}
s.update({6,8,90})
s
# Out:
# {5, 6, 7, 8, 9, 90}

# %%
s={5,7,9}
s.add({6,8,90})
s
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_17792\2745368492.py in <module>
#       1 s={5,7,9}
# ----> 2 s.add({6,8,90})
#       3 s
#
# TypeError: unhashable type: 'set'

# %%
s={5,7,9}
s.add((6,8,90))
s
# Out:
# {(6, 8, 90), 5, 7, 9}

# %%
s={4,6,7,90}
s.remove(90)
s
# Out:
# {4, 6, 7}

# %%
s={4,6,7,90}
s.remove(900)#  
s
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_17792\453542519.py in <module>
#       1 s={4,6,7,90}
# ----> 2 s.remove(900)
#       3 s
#
# KeyError: 900

# %%
s={4,6,7,90}
s.discard(900)  #
s
# Out:
# {4, 6, 7, 90}

# %%
s={4,6,7,90}
s.pop()
s
# Out:
# {4, 6, 7}

# %%
s={4,6,7,90,9000000000000,'p',6555,9.8}
s.pop()  # it can any item to remove
# Out:
# 9000000000000

# %%
s.clear()

# %%
s={4,6,7,90,9000000000000,'p',6555,9.8}
del s

# %%
s1={1,2,3,4,5}
s2={3,4,5}
s1.issuperset(s2)
# Out:
# True

# %%
s1={1,2,3,4,5}
s2={3,4,5,8,9}
s1.issuperset(s2)
# Out:
# False

# %%
for i in range(1, 6):                     #ab
    for j in range(1, i + 1):             # aabb
        print(j, end="")                   #aaabbb
    print()                                 # aaaaaaaabbbb
# Out:
# 1
# 12
# 123
# 1234
# 12345

# %%
# dictionary   both sore the keyvalues
d={}
type(d)
# Out:
# dict

# %%
d={'name':'a','sub':'ds','age':28}
type(d)
# Out:
# dict

# %%
d.keys()
# Out:
# dict_keys(['name', 'sub', 'age'])

# %%
d.values()
# Out:
# dict_values(['a', 'ds', 28])

# %%
d.items()
# Out:
# dict_items([('name', 'a'), ('sub', 'ds'), ('age', 28)])

# %%
d={'name':'hitha',
  'age':22,
  'place':'blr',
  'marks':{'ds':90,'ai':95}}

# %%
d['name']
# Out:
# 'hitha'

# %%
d['marks']['ds']
# Out:
# 90

# %%
d['marks']['ai']
# Out:
# 95

# %%
d={'name':'hitha',
  'age':22,
  'place':'blr',
  'marks':{'ds':90,'ai':95},
  'salary':[8,9,90]}

# %%
d['salary'][1]
# Out:
# 9

# %%
d['salary'][2]
# Out:
# 90

# %%
d={'name':'hitha',
  'age':22,
  'place':'blr',
  'marks':{'ds':90,'ai':95},
  'salary':[8,9,90],
  'hobby':('music','boxing','gym')}

# %%
d['hobby'][1]
# Out:
# 'boxing'

# %%
d={(1,2,3,4):'p','name':'a'}

# %%
d={{1,2,3,4}:'p','name':'a'}
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_17792\4147909178.py in <module>
# ----> 1 d={{1,2,3,4}:'p','name':'a'}
#
# TypeError: unhashable type: 'set'

# %%
# as a (key) can we use the list no
# can we use the tuple yes
# can we use the set no

# %%
# i want to change the name
d={'name':'hitha',
  'age':22,
  'place':'blr',
  'marks':{'ds':90,'ai':95},
  'salary':[8,9,90],
  'hobby':('music','boxing','gym')}
d['name']='bhunu'
d
# Out:
# {'name': 'bhunu',
#  'age': 22,
#  'place': 'blr',
#  'marks': {'ds': 90, 'ai': 95},
#  'salary': [8, 9, 90],
#  'hobby': ('music', 'boxing', 'gym')}

# %%
d={'name':'hitha',
  'age':22,
  'place':'blr',
  'marks':{'ds':90,'ai':95},
  'salary':[8,9,90],
  'hobby':('music','boxing','gym')}
d['age']=30
d
# Out:
# {'name': 'hitha',
#  'age': 30,
#  'place': 'blr',
#  'marks': {'ds': 90, 'ai': 95},
#  'salary': [8, 9, 90],
#  'hobby': ('music', 'boxing', 'gym')}

# %%
d={'name':'hitha',
  'age':22,
  'place':'blr',
  'marks':{'ds':90,'ai':95},
  'salary':[8,9,90],
  'hobby':('music','boxing','gym')}
d['marks']['ai']=67
d
# Out:
# {'name': 'hitha',
#  'age': 22,
#  'place': 'blr',
#  'marks': {'ds': 90, 'ai': 67},
#  'salary': [8, 9, 90],
#  'hobby': ('music', 'boxing', 'gym')}

# %%
d={'name':'hitha',
  'age':22,
  'place':'blr',
  'marks':{'ds':90,'ai':95},
  'salary':[8,9,90],
  'hobby':('music','boxing','gym')}
d['salary'][1]=9000
d
# Out:
# {'name': 'hitha',
#  'age': 22,
#  'place': 'blr',
#  'marks': {'ds': 90, 'ai': 95},
#  'salary': [8, 9000, 90],
#  'hobby': ('music', 'boxing', 'gym')}

# %%
d.pop('hobby')
# Out:
# ('music', 'boxing', 'gym')

# %%
d.pop('salary')
# Out:
# [8, 9000, 90]

# %%
d={'name':'hitha',
  'age':22,
  'place':'blr',
  'marks':{'ds':90,'ai':95},
  'salary':[8,9,90],
  'hobby':('music','boxing','gym')}
d['salary'][1]=9000
del d['age']
d
# Out:
# {'name': 'hitha',
#  'place': 'blr',
#  'marks': {'ds': 90, 'ai': 95},
#  'salary': [8, 9000, 90],
#  'hobby': ('music', 'boxing', 'gym')}

# %%
d={'name':'hitha',
  'age':22,
  'place':'blr',
  'marks':{'ds':90,'ai':95},
  'salary':[8,9,90],
  'hobby':('music','boxing','gym')}
d['salary'][1]=9000
d.clear()
d
# Out:
# {}

# %%
d={'name':'deep','age':2,'sub':'ds'}

# %%
for i in d.items():
    print(i)
# Out:
# ('name', 'deep')
# ('age', 2)
# ('sub', 'ds')

# %%
for i in d:
    print(i)
# Out:
# name
# age
# sub

# %%
for i in d.values():
    print(i)
# Out:
# deep
# 2
# ds

# %%
for i in d:
    print(i,d[i])
# Out:
# name deep
# age 2
# sub ds

# %%
d1={1:2,3:4,4:5}
d2={4:7,6:8}
d1.update(d2)
print(d1)
# Out:
# {1: 2, 3: 4, 4: 7, 6: 8}

# %%
d1={1:2,3:4,4:5}
d2={4:7,6:8,3:90}
d1.update(d2)
print(d1)
# Out:
# {1: 2, 3: 90, 4: 7, 6: 8}

# %%
for i in range(1, 8):

    # print a
    for j in range(i):
        print("a", end="")

    # print b
    for k in range(i // 2 + 1):
        print("b", end="")

    print()
# Out:
# ab
# aabb
# aaabb
# aaaabbb
# aaaaabbb
# aaaaaabbbb
# aaaaaaabbbb
