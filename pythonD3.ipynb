# %%
s='welcome to python'
s[-11:-16:-1]
# Out:
# 'emocl'

# %%
s='welcome to python'
s[-12:-16:-1]
# Out:
# 'mocl'

# %%
s='welcome to python'
s[-7:-16:-3]
# Out:
# '  o'

# %%
'abc'*4
# Out:
# 'abcabcabcabc'

# %%
'Abc'>'abc'
# Out:
# False

# %%
'hi' and 'python'
# Out:
# 'python'

# %%
'boxing' and 'mma' # best of second value is result
# Out:
# 'mma'

# %%
'boxing' or 'mma'
# Out:
# 'boxing'

# %%
'manu'or 'manju'
# Out:
# 'manu'

# %%
'manu'and 'manju'
# Out:
# 'manju'

# %%
'' and 'abc'
# Out:
# ''

# %%
' ' and 'abc'
# Out:
# 'abc'

# %%
min(s)
# Out:
# ' '

# %%
max(s)
# Out:
# 'y'

# %%
sorted(s)
# Out:
# [' ',
#  ' ',
#  'c',
#  'e',
#  'e',
#  'h',
#  'l',
#  'm',
#  'n',
#  'o',
#  'o',
#  'o',
#  'p',
#  't',
#  't',
#  'w',
#  'y']

# %%
sorted(s,reverse=True)
# Out:
# ['y',
#  'w',
#  't',
#  't',
#  'p',
#  'o',
#  'o',
#  'o',
#  'n',
#  'm',
#  'l',
#  'h',
#  'e',
#  'e',
#  'c',
#  ' ',
#  ' ']

# %%
s='hi python'
s.capitalize()
# Out:
# 'Hi python'

# %%
s='python'
s.capitalize()
# Out:
# 'Python'

# %%
s.title()
# Out:
# 'Python'

# %%
s='welcome to python'
s.title()
# Out:
# 'Welcome To Python'

# %%
s='welcome to python'
s.upper()
# Out:
# 'WELCOME TO PYTHON'

# %%
s='WELCOME TO PYTHON'
s.lower()
# Out:
# 'welcome to python'

# %%
s='Welcome'
s.swapcase()
# Out:
# 'wELCOME'

# %%
# upper -- entire sent will be capital
# lower -- entire sent will be lower
# capitalize --- only first letter from sent
# title --- entire in each word starting word is capital
# swapcase -- capital will become
# small and -----

# %%
s='welcome to python'
s.count('o')
# Out:
# 3

# %%
s='welcome to python'
s.count('n')
# Out:
# 1

# %%
s='welcome to python'
s.find('n')
# Out:
# 16

# %%
s='welcome to python'
s.find('i')
# Out:
# -1

# %%
s='welcome to python'
s.find('t')
# Out:
# 8

# %%
s='welcome to python'
s.find('x')
# Out:
# -1

# %%
s='welcome to python'
s.find('o')
# Out:
# 4

# %%
s='welcome to python'
s.find('o:o')
# Out:
# -1

# %%
s='welcome to python'
s.find(' to ')
# Out:
# 7

# %%
s='welcome to python'
s.index('t')
# Out:
# 8

# %%
s='welcome to python'
s.index('z')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_21184\2269682416.py in <module>
#       1 s='welcome to python'
# ----> 2 s.index('z')
#
# ValueError: substring not found

# %%
# index and find
# if char is not there index will
# give the error
# find -1
# index given error is ValueError' substring not found'

# %%
s.startswith('s')
# Out:
# False

# %%
s.startswith('w')
# Out:
# True

# %%
s.endswith('s')
# Out:
# False

# %%
s.endswith('n')
# Out:
# True

# %%
s.endswith('t')
# Out:
# False

# %%
  # true or false
# isalnum ---alphabet,numarical,alpha numarical
# isalpha --- only alphabet(true),in between space is there(false)
# isdigital --- only numarical and also only int
# isidentifier --- only alpha and (_) is true ,both are special char is false,its also only in int not in decimal

# %%
a='python123'
a.isalnum()
# Out:
# True

# %%
a='abc123'
a.isalnum()
# Out:
# True

# %%
a='123'
a.isalnum()
# Out:
# True

# %%
a='&123'
a.isalnum()
# Out:
# False

# %%
a='mma'
a.isalpha()
# Out:
# True

# %%
a='mma123'
a.isalpha()
# Out:
# False

# %%
a='123'
a.isalpha()
# Out:
# False

# %%
a='d g'
a.isalpha()
# Out:
# False

# %%
a='d g'
a.isdigit()
# Out:
# False

# %%
a='dog123'
a.isdigit()
# Out:
# False

# %%
a='123'
a.isdigit()
# Out:
# True

# %%
a='123.7'
a.isdigit()
# Out:
# False

# %%
a='45a'
a.isidentifier()
# Out:
# False

# %%
a='a45'
a.isidentifier()
# Out:
# True

# %%
a='_a45'
a.isidentifier()
# Out:
# True

# %%
a='where'
a.isidentifier()
# Out:
# True

# %%
a='%op'
a.isidentifier()
# Out:
# False

# %%
a='_%op'
a.isidentifier()
# Out:
# False

# %%
a='_op'
a.isidentifier()
# Out:
# True

# %%
a='_op8'
a.isidentifier()
# Out:
# True

# %%
a9=5
a.isidentifier()
# Out:
# True

# %%
a9.0=5
a.isidentifier()
# Out:
#   File "C:\Users\anand\AppData\Local\Temp\ipykernel_21184\2644585682.py", line 1
#     a9.0=5
#        ^
# SyntaxError: invalid syntax

# %%
# join -- list to str
# split ---str to list

# %%
'my name is python'.split()
# Out:
# ['my', 'name', 'is', 'python']

# %%
' '.join(['my', 'name', 'is', 'python'])
# Out:
# 'my name is python'

# %%
'my name is python'.replace('p','c')
# Out:
# 'my name is cython'

# %%
'my name is python'.replace('p','w')
# Out:
# 'my name is wython'

# %%
'my name is python'.replace('python','c')
# Out:
# 'my name is c'

# %%
'a      '.strip()
# Out:
# 'a'

# %%
'my name is python'.strip()
# Out:
# 'my name is python'

# %%
'   a     '.lstrip()
# Out:
# 'a     '

# %%
'    a      '.rstrip()
# Out:
# '    a'

# %%
# format
a='python'
b='prog'
s='my name is {0},i am {1}'   # 0 is python ,1 is prog
s.format(a,b)
# Out:
# 'my name is python,i am prog'

# %%
a='python'
b='prog'
s='my name is {0},i am {1}'
s.format(b,a)
# Out:
# 'my name is prog,i am python'

# %%
a='python'
b='prog'
s='my name is {1},i am {0}'
s.format(b,a)
# Out:
# 'my name is python,i am prog'

# %%
a='python'
b='prog'
s='my name is {0},i am {0}'
s.format(b,a)
# Out:
# 'my name is prog,i am prog'

# %%
a='boxing'
b='sports'
f='my name is {avd} it is {dfg}'
f.format(a,b)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_21184\3969023455.py in <module>
#       2 b='sports'
#       3 f='my name is {avd} it is {dfg}'
# ----> 4 f.format(a,b)
#
# KeyError: 'avd'

# %%
a='boxing'
b='sports'
f'my name is {a} it is {b}'
# Out:
# 'my name is boxing it is sports'

# %%
# conditional statement
a=9
if a>9:
print
# Out:
#   File "C:\Users\anand\AppData\Local\Temp\ipykernel_21184\847034652.py", line 4
#     print
#         ^
# IndentationError: expected an indented block

# %%
# conditional statement
a=9
if a>5:
    print(a)
# Out:
# 9

# %%
# conditional statement
a=9
if a>5:
    print('yes')
# Out:
# yes

# %%
# conditional statement
a=9
if a>59:
    print('yes')
else:
    print('no')
# Out:
# no

# %%
a=9
if a<59:
    print('yes')
else:
    print('no')
# Out:
# yes

# %%
# to check student will go for school or not
age=int(input("Enter your age"))
if age>=18:
    print('college')
else:
    print('school')
# Out:
# Enter your age16
# school

# %%
# to check student will go for school or not
age=int(input("Enter your age"))
if age>=18:
    print('college')
else:
    print('school')
# Out:
# Enter your age55
# college

# %%
# to check student will go for school or not
age=int(input("Enter your age"))
if age>=18 and age <=23:
    print('college')
else:
    print('school')
# Out:
# Enter your age65
# school

# %%
# to check student will go for school or not
age=int(input("Enter your age"))
if age>=18 and age <=23:
    print('college')
else:
    print('school')
# Out:
# Enter your age21
# college

# %%
# check the number is even or odd
num=int(input("enter the number"))
if num%2==0:
    print('even')
else:
    print('odd')
# Out:
# enter the number34
# even

# %%
num=int(input("enter the number"))
if num%2==0:
    print('even')
else:
    print('odd')
# Out:
# enter the number5
# odd

# %%
num=int(input("enter the number"))
if num/2==0:
    print('even')
else:
    print('odd')
# Out:
# enter the number3
# odd

# %%
num=int(input("enter the number"))
if num/2==0:
    print('even')
else:
    print('odd')
# Out:
# enter the number76
# odd
