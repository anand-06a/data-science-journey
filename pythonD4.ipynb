# %%
# check the string is palindrom or not
s=input('enter the string')
if s==s[::-1]:
    print('palindrom')
else:
    print('not palindrom')
# Out:
# enter the stringeye
# palindrom

# %%
# check the string is palindrom or not
s=input('enter the string')
if s==s[::-1]:
    print('palindrom')
else:
    print('not palindrom')
# Out:
# enter the stringasds
# not palindrom

# %%
# check the number is +ve or -ve
num=int(input('enter the number'))
if num<0:
    print('-ve')
else:
    print('+ve')
# Out:
# enter the number6
# +ve

# %%
num=int(input('enter the number'))
if num>0:
    print('+ve')
else:
    print('---ve')
# Out:
# enter the number8
# +ve

# %%
n=int(input('enter the number'))
if n<0:
    print('+ve')
elif n==0:
    print('zero')
elif n<0:
    print('-ve')
# Out:
# enter the number6

# %%
n=int(input('enter the number'))
if n>0:
    print('+ve')
elif n==0:
    print('zero')
elif n<0:
    print('-ve')
else:
    print('nothing!!!')
# Out:
# enter the number7
# +ve

# %%
# age 3--17  school
# age 18 to 28 college
# job 28 above
age=int(input('enter the number'))
if age>=3 and age<=17:
    print('school')
elif age>=18 and age <=28:
    print('college')
else:
    print('job')
# Out:
# enter the number8
# school

# %%
age=int(input('enter the number'))
if age>=3 and age<=17:
    print('school')
elif age>=18 and age <=28:
    print('college')
else:
    print('job')
# Out:
# enter the number28
# college

# %%
age=int(input('enter the number'))
if age>=3 and age<=17:
    print('school')
elif age>=18 and age <=28:
    print('college')
else:
    print('job')
# Out:
# enter the number65
# job

# %%
# if the temperature 30 to 50 hot
# if the temperature 10 to 29 modarate
# if the temperature 1 to 9 cool
# less than one than write don't go anywhere
temp=eval(input('enter the number'))
if temp>=30 and temp<=50:
    print('hot')
elif temp>=10 and temp<=29:
    print('moderate')
elif temp>=1 and temp<=9:
    print('cool')
else:
    print('normal')
# Out:
# enter the number34
# hot

# %%
temp=eval(input('enter the number'))
if temp>=30 and temp<=50:
    print('hot')
elif temp>=10 and temp<=29:
    print('moderate')
elif temp>=1 and temp<=9:
    print('cool')
else:
    print("do't go anywhere")
# Out:
# enter the number65
# do't go anywhere

# %%
temp=eval(input('enter the number'))
if temp>=30 and temp<=50:
    print('hot')
elif temp>=10 and temp<=29:
    print('moderate')
elif temp>=1 and temp<=9:
    print('cool')
else:
    print('normal')
# Out:
# enter the number2
# cool

# %%
# if are trying to login in insta
# if ur user_email=='ad123@gmail.com'
# if password=='m123@'
# login done
# user_email !='ad123@gmail.com' and password!='m123@'
# unable to login
user_email=input('enter email_id')
password=input('enter password')
if user_email=='ad123@gmail.com' and
# Out:
# enter email_idaralianu2004@gmail.com
# enter passwordanand34@
# unable to login

# %%
user_email=input('enter email_id')
password=input('enter password')
if user_email=='ad123@gmail.com' and password=='m123@':
    print('login done')
else:
    print('unable to login')
# Out:
# enter email_idagsgd87@gmail.com
# enter passwordafd32@
# unable to login

# %%
user_email=input('enter email_id')
password=input('enter password')
if user_email=='ad123@gmail.com' and password=='m1@32':
    print('login done')
else:
    print('unable to login')
# Out:
# enter email_idasgdf223@gmail.com
# enter passwordman3@657
# unable to login

# %%
user_email=input('enter email_id')
password=input('enter password')
if user_email=='ad123@gmail.com' and password=='m123@':
    print('login done!!!!!!')
else:
    print('unable to login')
# Out:
# enter email_idancn123@gmail.com
# enter passwordmcnjd12@
# unable to login

# %%
user_email=input('enter email_id')
password=input('enter password')
if user_email=='ad123@gmail.com' and password=='m1@32':
    print('login done')
elif user_email !='ad123@gmail.com' and password!='m123@':
    print('wrong password')
else:
    print('unable to login')
# Out:
# enter email_idancn123@gmail.com
# enter passworda154@
# wrong password

# %%
user_email=input('enter email_id')
password=input('enter password')
if user_email=='ad123@gmail.com' and password=='m123@':
    print('login done')
elif user_email=='ad123@gmail.com' and password!='m123@':
    print('wrong password')
    password=input('enter password')
    if password=='m123@':
        print('correct password,login done')
    else:
        print('How you have forget password')
else:
    print('unable to login')
# Out:
# enter email_idancn123@gmail.com
# enter passworda123@
# unable to login

# %%
user_email=input('enter email_id')
password=input('enter password')
if user_email=='ad123@gmail.com' and password=='m123@':
    print('login done')
elif user_email=='ad123@gmail.com' and password!='m123@':
    print('wrong password')
    password=input('enter password')
    if password=='m123@':
        print('correct password,login done')
    else:
        print('How you have forget password')
else:
    print('unable to login')
# Out:
# enter email_idabbss34@gmail.com
# enter passworddghfh43@
# unable to login

# %%
user_email=input('enter email_id')
password=input('enter password')
if user_email=='ad123@gmail.com' and password=='m123@':
    print('login done')
elif user_email=='ad123@gmail.com' and password!='m123@':
    print('wrong password')
    password=input('enter password')
    if password=='m123@':
        print('correct password,login done')
    else:
        print('How you have forget password')
else:
    print('unable to login')
# Out:
# enter email_idad123@gmail.com
# enter passwordm123@
# login done

# %%
user_email=input('enter email_id')
password=input('enter password')
if user_email=='ad123@gmail.com' and password=='m123@':
    print('login done')
elif user_email=='ad123@gmail.com' and password!='m123@':
    print('wrong password')
    password=input('enter password')
    if password=='m123@':
        print('correct password,login done')
    else:
        print('How you have forget password')
else:
    print('unable to login')
# Out:
# enter email_idad123@gmail.com
# enter password4=n433@
# wrong password
# enter passwordn544@
# How you have forget password

# %%
user_email=input('enter email_id')
password=input('enter password')
if user_email=='ad123@gmail.com' and password=='m123@':
    print('login done')
elif user_email=='ad123@gmail.com' and password!='m123@':
    print('wrong password')
    password=input('enter password')
    password=='m123@':
        print('correct password,login done')
    else:
        print('How you have forget password')
else:
    print('unable to login')
# Out:
#   File "C:\Users\anand\AppData\Local\Temp\ipykernel_11136\4089783126.py", line 8
#     elif password=='m123@':
#        ^
# SyntaxError: invalid syntax
